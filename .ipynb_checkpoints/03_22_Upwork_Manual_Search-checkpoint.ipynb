# %%
#read freelancer data

#initialize
from selenium import webdriver
import time
import string, sys
import csv
from datetime import datetime
from selenium.webdriver.common.by import By
import selenium.webdriver.support.expected_conditions as EC
import selenium.webdriver.support.ui as ui
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pandas as pd

import time

#wr=open('output.csv','w')
timestamp=datetime.now()
path_to_chromedriver = r"chromedriver.exe"
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# %%
#login
url=r'https://www.upwork.com/'
browser.get(url)

# %%
#enter search criteria
url=r'https://www.upwork.com/ab/profiles/search/'
browser.get(url)
# time.sleep(3)
# browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[1]/freelancer-facet-search/freelancer-search/freelancer-search-form/div/div[1]/div').click()
# #$1 dollar earned
# browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[1]/freelancer-facet-search/freelancer-search/facet-panel/div/div[1]/div[1]/facet-input-radio-list/div/div[2]/label/input').click()
# #last worked
# browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[1]/freelancer-facet-search/freelancer-search/facet-panel/div/div[2]/div[4]/facet-input-radio-list/div/div[2]/label/input').click()
# #categories
# browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[1]/freelancer-facet-search/freelancer-search/facet-panel/div/div[2]/div[1]/facet-input-category/div/div[4]/a').click()

# %%
#search
#freelancer list

# list.find_element_by_class_name()

f=open('people3.csv','w')
f.write('imageurl;profileurl;name;title;description;wage;earned;status;location\n')
# Out:
# 71

# %%
count=0
nextbutton=True
while nextbutton==True:
    time.sleep(1)
                                        #//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[2]
    #list=browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/div/div/div/div[1]/div/freelancers-search/div/div[2]')
    list=browser.find_element_by_class_name('ats-applicants')
    people=list.find_elements_by_tag_name('article')
    
    for p in people:
        
        image=p.find_element_by_class_name('col-md-10')
        div=image.find_element_by_tag_name('div')
        # driver.find_element_by_xpath('//input[@node-type="searchInput"]')
        # driver.find_elements_by_xpath('.//span[contains(text(), "Author")]/a')
        #print('------')
        imageurl=div.get_attribute('data-photo-url')
        #print(imageurl)

        content=p.find_element_by_class_name('col-md-9')
        namediv=content.find_element_by_tag_name('a')
        name=namediv.text
        profileurl=namediv.get_attribute('href')

        title=content.find_element_by_tag_name('strong').text
        #print(name,profileurl,title)
        print(name)
        description = content.find_element_by_xpath('//p[@data-qa="tile_description"]').text
        #print(description)

        details=content.find_element_by_class_name('m-0-bottom')
        detailslist=['wage','earned','success(opt)','location']
        detailsvals=[]
        for d in details.find_elements_by_class_name('col-md-3'):
            t = d.text.strip()
            #print(t)
            detailsvals.append(t)   

        f.write('%s;%s;%s;%s;%s;%s\n' % (imageurl,profileurl,name.encode(encoding='UTF-8',errors='strict'),title.encode(encoding='UTF-8',errors='strict'),description.encode(encoding='UTF-8',errors='strict'),";".join(detailsvals)))
        #next button
        #https://www.upwork.com/ab/profiles/search/?revenue=1&rate=10-30&last=15&c=writing&sc=article-blog-writing
    try:

        child=browser.find_element_by_xpath('//a[contains(text(), "Next ›")]')
        parent=child.find_element_by_xpath('..')
        # child.is_disabled
        classes = parent.get_attribute("class");

        if 'disabled' in classes:
            f.close()
            nextbutton=False
            print('disabled')
        else:

            child.click()
            time.sleep(3)
            print("--New Page--")

    except:
        f.close()
        nextbutton=False
        
    count+=1
    print(count)
# Out:
# Diana Eastman
# Sarah C.
# Constance H.
# Geofrey N.
# Mir Rajibul Islam
# Daniel K.
# Colette C.
# Lucian Crăciun
# Brenda Neugent
# Deborah S.
# --New Page--
# 1
# Anastazija M.
# Nhung Thi Dang
# Diamond G.
# Asma Ghuidhaoui
# Kimberly Davis
# Maria Stepanova
# Sofía Félix Poggi
# Raquel R.
# Rosemary Anne K.
# Jessica Coppola
# --New Page--
# 2
# Michelle R.
# Javiera Salamanca
# John McCoy
# Riza Parungao
# Kevin Beane
# Rebecca L.
# Victoria B.
# Ishank badhani
# Stefan B.
# Ilan Ades
# --New Page--
# 3
# Florian Gheorghe
# Kehsi I.
# Gillian Birch
# Summer Hirst
# Ahmed S.
# Mariangela Sapere
# Jeanette G.
# Taru B.
# Angela S.
# Deborah Clothier
# --New Page--
# 4
# Lynn S.
# Gretha G.
# Christin G.
# Rachael C.
# Anthony Tyler
# Svetlana Khrenkova
# Areeba Ajanee
# Gregory Gambone
# Daniela Caro
# Cayla McDonald
# --New Page--
# 5
# Chad Ghormley
# Henry Allen
# DeAnna McIntosh
# Wendy K.
# Cristina Gómez
# Sunita Vellapally
# Cate Strogonova
# Miguel B.
# Guydo J.
# Rebecca L.
# --New Page--
# 6
# Nandita N.
# Ahmed Moustafa
# Alberto Rodriguez
# Janina S.
# Usman Ali Qureshi
# James M.
# Christophe C.
# Carrie Cathey
# Gaia Della Casa
# Karri M.
# --New Page--
# 7
# Robin Bailes
# Shannon Nairn
# Michael R.
# Haseeb Ahsen
# Erika Nicolosi
# Britt S.
# Mayumi Anzai
# Rupanshi M.
# Jessica Contreras
# Rahul S
# --New Page--
# 8
# Ahmed Rafi
# Daria P.
# Mariann H.
# Pat B.
# Traistaru L.
# Shuhao Y.
# Valentina D'Egidio
# Andrea B.
# Michael R.
# Jorrit O.
# --New Page--
# 9
# Mayumi Anzai
# Rupanshi M.
# Christina Stausholm Johansen
# Vianne P.
# Daria Temerbek
# Palmerino Di Berardino
# Daniela Monteiro
# Magdalena G.
# Jeff L.
# Shiya Shamsu
# --New Page--
# 10
# André J.
# Tetiana S.
# Jimmie Castillo
# Susan Wahl
# Cinzia N.
# Fernanda V.
# Alex F.
# Bart Platteeuw
# Sarah A.
# Silvana O.
# --New Page--
# 11
# Candy Zuo
# Cameron Devall
# Robin Williams
# Diogo Garcia
# Nick Masercola
# Yoko I.
# Sarah Ingraham
# --New Page--
# 26
# Marili N.
# Adriana Bringuenti
# Maria B.
# Daniel Darío Estrada
# Marcos Chaves
# Tim Sutton
# Huda Y.
# Bothaina Saleh
# John Baldwin
# Anissa Mathias
# --New Page--
# 27
# Andriamiadana R.
# Marcel Sanromà
# Sarah F.
# Ben Wilson
# Louise Egea
# Yoko I.
# Anthea T.
# Bartosz Spytkowski
# Sofia Di Lauro
# Carla Jonas
# disabled
# 28

# %%
f.close()

# %%
# next=browser.find_element_by_xpath('//ul[@class="pagination"]')
next=browser.find_elements_by_class_name('pagination')[1]

# %%
next
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="fc5b7405a361a4f67d0b88c835b9bafb", element="0.853887760899138-116")>

# %%
browser.find_element_by_xpath('//a[contains(text(), "Next ›")]').click()
time.sleep(2)

# %%
da.text
# Out:
# 'Next ›'

# %%
da.click()

# %%
child=browser.find_element_by_xpath('//a[contains(text(), "Next ›")]')
parent=child.find_element_by_xpath('..')
# child.is_disabled
classes = parent.get_attribute("class");
classes
# Out:
# 'pagination-next disabled'

# %%
#Read Data
import pandas
file='people.csv'
df=pandas.read_csv(file,sep=";")

# %%
#remove duplicates
df2=df.drop_duplicated()
print(df2.shape())
print(df2.shape())

# %%
import pandas as pd
from MutiprocessDataframe import callfunction
import numpy as np

# %%
basefolder=r'C:\Users\amac\Documents\Development\0117-DaiAnalysis\Upwork\manual_people'
print ("Calling MultiProcess")
resourceslist = callfunction(basefolder)
resourceslist.shape
# Out:
# Calling MultiProcess
# (4948, 10)

# %%
df2=resourceslist.drop_duplicates()

# %%
list(df2.columns.values)
# Out:
# ['imageurl',
#  'profileurl',
#  'name',
#  'title',
#  'description',
#  'wage',
#  'earned',
#  'status',
#  'location',
#  'filename']

# %%
df2.head()
renamecolumns={'imageurl': 'portrait_50','profileurl': 'id','wage': 'rate','status': 'feedback','location': 'country'}

# %%
df2=df2.rename(columns=renamecolumns)

# %%
df2.head()
# Out:
#                                          portrait_50  \
# 0  https://odesk-prod-portraits.s3.amazonaws.com/...
# 1  https://odesk-prod-portraits.s3.amazonaws.com/...
# 2  https://odesk-prod-portraits.s3.amazonaws.com/...
# 3  https://odesk-prod-portraits.s3.amazonaws.com/...
# 4  https://odesk-prod-portraits.s3.amazonaws.com/...
#
#                                                   id              name  \
# 0  https://www.upwork.com/freelancers/~012dc4249a...   Genevieve Crotz
# 1  https://www.upwork.com/freelancers/~0182735f50...  Md. Atiar Rahman
# 2  https://www.upwork.com/freelancers/~010a19f56f...      Ayesha Athar
# 3  https://www.upwork.com/freelancers/~017d09a887...       Silviu Fera
# 4  https://www.upwork.com/freelancers/~0174a530e2...    Md Asif Rahman
#
#                                                title  \
# 0                     Creative Blog & Article Writer
# 1                          Article and Blog Writer .
# 2  Beauty, Lifestyle, Fashion Blog and Article Wr...
# 3                 Article and Blog writer, Wordpress
# 4  Pro Copywriter, Article/Blog writer with SEO k...
#
#                                          description         rate  \
# 0  The written word is my specialty! I am a freel...  $18.00 / hr
# 1  The written word is my specialty! I am a freel...  $11.00 / hr
# 2  The written word is my specialty! I am a freel...  $15.00 / hr
# 3  The written word is my specialty! I am a freel...  $16.66 / hr
# 4  The written word is my specialty! I am a freel...  $13.75 / hr
#
#          earned          feedback        country    filename
# 0  $400+ earned               NaN  United States  people.csv
# 1   $2k+ earned   95% Job Success     Bangladesh  people.csv
# 2   $1k+ earned   92% Job Success       Pakistan  people.csv
# 3   $1k+ earned  100% Job Success        Romania  people.csv
# 4  $20k+ earned   91% Job Success     Bangladesh  people.csv

# %%
df2.to_csv("manual_people.csv")

# %%
from selenium import webdriver
import time
import string, sys
import csv
from datetime import datetime
from selenium.webdriver.common.by import By
import selenium.webdriver.support.expected_conditions as EC
import selenium.webdriver.support.ui as ui
from selenium.webdriver.common.action_chains import ActionChains
from selenium.webdriver.common.keys import Keys
import pandas as pd

import time

#wr=open('output.csv','w')
timestamp=datetime.now()
path_to_chromedriver = r"chromedriver.exe"
browser = webdriver.Chrome(executable_path = path_to_chromedriver)

# %%
def login(params):
    url=r"https://www.upwork.com/ab/account-security/login"
    url=r"https://www.upwork.com/ab/jobs-home/1189733"
    browser.get(url)
    time.sleep(4)

    ##browser.switch_to_frame(browser.find_elements_by_tag_name("iframe")[0])
    #recap=browser.find_element_by_class_name("g-recaptcha")
    ## move the driver to the first iFrame
    #browser.switch_to_frame(browser.find_elements_by_tag_name("iframe")[0])
    ## *************  locate CheckBox  **************
    #CheckBox = browser.find_element_by_id("recaptcha-anchor")
    #time.sleep(1)
    #CheckBox.click()
    username=params[0]
    password=params[1]
    ui.WebDriverWait(browser, 60).until(EC.visibility_of_element_located((By.ID, "login_username")))
    id=browser.find_element_by_id('login_username')
    id.send_keys(username)
    pw=browser.find_element_by_id('login_password')
    pw.send_keys(password)
    #click
    browser.find_element_by_tag_name('button').click()

    checkcaptcha(params)

    try:
        browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div[1]/div/a')
        browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div[2]/div[2]/div/div/div/table')
    except:
        try:
            browser.find_element_by_xpath('//*[@id="layout"]/div[2]/div[2]/div/div/h1')
        except:
            try:
                browser.find_element_by_xpath('//*[@id="skinny-nav"]/ul[2]/li[4]/a/span[1]').click()
                time.sleep(1)
                browser.find_element_by_xpath('//*[@id="skinny-nav"]/ul[2]/li[4]/ul/li[2]/ul/li[2]/a/div/div').click()
                time.sleep(1)
            except:
                pass

        checkcaptcha(params)

        #ActionChains(browser).move_to_element(hover).click(click).perform()

    time.sleep(2)
    # browser.get('https://www.upwork.com/ab/jobs-home/1189733')
    #ui.WebDriverWait(browser, 30).until(EC.visibility_of_element_located((By.CLASS_NAME, "twist-table")))
    #a=1

# %%
params=['low.jennifer.miller0921@gmail.com','ra123456.']
login(params)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-62-6ac88a28ed13> in <module>()
#       1 params=['low.jennifer.miller0921@gmail.com','ra123456.']
# ----> 2 login(params)
#
# <ipython-input-61-f2bc57b09ecb> in login(params)
#      23     browser.find_element_by_tag_name('button').click()
#      24
# ---> 25     checkcaptcha(params)
#      26
#      27     try:
#
# NameError: name 'checkcaptcha' is not defined

# %%
count=1
#dfresource=pd.read_csv(inputfile)
start=0
stop=2000
messagetext ="test %s %s %s"
amount=10
create='F'
negot='F'
mod=4

# %%
#https://www.upwork.com/freelancers/_~01ff203de58fed31fb/
df=df2[start:stop].copy()
df['worked']=''
df['jobs']=''
df['earned']=''
df['accolade']=''
df['success']=''
df['availability']=''
df['messaged']=""
df['job_in_progress']=''
df['scraped_rate']=''
df['language']=''
df['college']=''

f=open('catcherrors.txt','w')
f.write("url,worked,jobs,earned,accolade,success,availability,messaged,job_in_progress,scraped_rate,language,college")
count=0

for index, row in df.iterrows():
    count+=1
    print(count)
    if count%10<mod:
        #print row['c1'], row['c2']
        freeurl=row['id']
        # list = open(r"C:\Development\0117-DaiAnalysis\Upwork\freelancelist.txt",'r')
        browser.get(freeurl)
        time.sleep(3)

        try:
            rising=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[2]/h5/top-rated/div/span').text

        except:
            browser.get(freeurl)
            time.sleep(2)
        #search for ratings elements adn stuff..
        try:
            rising=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[2]/h5/top-rated/div/span').text
        except:
            try:
                rising=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[2]/h5[2]/top-rated/div/span[1]').text
            except:
                rising=''
        # //*[@id="oProfilePage"]/div[2]/section[2]/h5/top-rated/div/span #rising talent
        # //*[@id="oProfilePage"]/div[2]/section[2]/h5[2]/top-rated/div/span[1] #toprated with high job success
        # //*[@id="oProfilePage"]/div[2]/section[2]/h5[2]/top-rated/div/span[1]

        #success
        try:
            success=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[2]/h5[1]/o-job-success/div/div/span').text
        except:
            success=''

        try:
            rate=browser.find_element_by_xpath('//*[@id="optimizely-header-container-default"]/div[1]/div[1]/div/div[2]/h2/div/span/span[1]').text
        except:
            rate=''

        #Availability
        try:
            availsec=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/div[3]')
            availdivs=availsec.find_elements_by_tag_name('div')
            availtext=''
            for div in availdivs:
                line=div.text
                availtext+=line
        except:
            print('availab')

        availtext=''.join(availtext.splitlines())
        #work history

        try:
            language=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/o-profile-languages/div/ul/li/div/span[1]').text
        except:
            language=""

        # //*[@id="oProfilePage"]/div[2]/section[2]/div
        # //*[@id="oProfilePage"]/div[2]/section[2]/div #with rising talent
        # //*[@id="oProfilePage"]/div[2]/section[2]/div
        worked="" # 16 hours worked
        jobs="" # 18 jobs
        earned="" # $900+ earned
        try:
            workhistorysect=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[2]/div')
            workdivs=workhistorysect.find_elements_by_tag_name('div')
            for div in workdivs:
                line=div.text
                linesplit=line.split(" ")
                if 'worked' in line:
                    worked=linesplit[0]
                if 'job' in line:
                    #CHECK JOBS
                    jobs=linesplit[0]
                if 'earned' in line:
                    earned=linesplit[0]
        except:
            print('worked')

        #in progress
        prognum=0
        try:
            progstr=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[1]/div[2]/o-profile-assignments/div/div/div[2]').text
            if progstr=='':
                a=b

            prognum=int(progstr.split(" ",1)[0])

        except:
            try:
                jobsdiv=browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[1]/div[2]/o-profile-assignments/div/div/ul')
                jd=jobsdiv.find_elements_by_tag_name('li')
                for j in jd:
                    prog=j.find_element_by_tag_name('em').text
                    if "in progress" in prog:
                        prognum+=1
            except:
                print('prog')

        college = ''
        try:
            clg=browser.find_element_by_xpath('//o-profile-education[@items="vpd.education"]')
            lists = clg.find_elements_by_tag_name('li')
            for l in lists:
                college = l.text
                college = college.encode('ascii', 'replace')
                a=1

        except:
            print('clg')

        time.sleep(1)

        #find invite element
        try:
            browser.find_element_by_xpath('//*[@id="oProfilePage"]/div[2]/section[1]/div[1]/div/button/span').click()
        except:
            pass
        time.sleep(2)

        #invite.click()
        try:
            textbox=browser.find_element_by_xpath('//*[@id="interview-invitation-popup-message"]')
            textbox.clear()
            first=row['name'].split(" ",1)[0].title()
            textbox.send_keys(messagetext % (first, negot, str(amount)))
            time.sleep(1)
        except:
            print ('message')

        #SEND MESSAGE
        if create=="T":
            try:
                browser.find_element_by_xpath('/html/body/div[2]/div[2]/div[1]/div/div/form/div/button').click()
                                #MARK AS SENT
                df.set_value(index,'messaged',"Y")
            except:
                try:
                    browser.find_element_by_xpath('/html/body/div[3]/div[2]/div[1]/div/div/form/div/button').click()
                                    #MARK AS SENT
                    df.set_value(index,'messaged',"Y")
                except:
                    df.set_value(index,'messaged',"N")
        else:
            df.set_value(index,'messaged',"NA")



        # if prognum==0:
        #     progrum=''
        # else:
        #     prognum=str(prognum)

        # df.loc[index,'new']=1
        df.set_value(index,'worked',worked)
        df.set_value(index,'jobs',jobs)
        df.set_value(index,'earned',earned)
        df.set_value(index,'accolade',rising)
        df.set_value(index,'success',success)
        df.set_value(index,'availability',availtext)
        df.set_value(index,'scraped_rate',rate)
        df.set_value(index,'job_in_progress',prognum)
        df.set_value(index,'language',str(language))
        df.set_value(index,'college',college)

        try:
            f.write(",".join([freeurl,worked,jobs,earned,rising,success,availtext,rate,str(prognum),language,college]))
        except:
            print('write')

    else:
        a=1
        
    time.sleep(2)
# Out:
# 1
# 2
# write
# 3
# prog
# write
# 4
# 5
# 6
# 7
# 8
# 9
# 10
# write
# 11
# prog
# write
# 12
# write
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20
# prog
# write
# 21
# prog
# write
# 22
# write
# 23
# write
# 24
# 25
# 26
# 27
# 28
# 29
# 30
# prog
# write
# 31
# prog
# write
# 32
# prog
# write
# 33
# write
# 34
# 35
# 36
# 37
# 38
# 39
# 40
# prog
# write
# 41
# write
# 42
# write
# 43
# write
# 44
# 45
# 46
# 47
# 48
# 49
# 50
# prog
# write
# 51
# write
# 52
# write
# 53
# write
# 54
# 55
# 56
# 57
# 58
# 59
# 60
# write
# 61
# write
# 62
# write
# 63
# write
# 64
# 65
# 66
# 67
# 68
# 69
# 70
# write
# 71
# write
# 72
# availab
# worked
# prog
# clg
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-64-74eb2026befc> in <module>()
#     139
#     140         #invite.click()
# --> 141         textbox=browser.find_element_by_xpath('//*[@id="interview-invitation-popup-message"]')
#     142         textbox.clear()
#     143         first=row['name'].split(" ",1)[0].title()
#
# C:\Users\amac\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_xpath(self, xpath)
#     291             driver.find_element_by_xpath('//div/td[1]')
#     292         """
# --> 293         return self.find_element(by=By.XPATH, value=xpath)
#     294
#     295     def find_elements_by_xpath(self, xpath):
#
# C:\Users\amac\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     750         return self.execute(Command.FIND_ELEMENT, {
#     751             'using': by,
# --> 752             'value': value})['value']
#     753
#     754     def find_elements(self, by=By.ID, value=None):
#
# C:\Users\amac\Anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     234         response = self.command_executor.execute(driver_command, params)
#     235         if response:
# --> 236             self.error_handler.check_response(response)
#     237             response['value'] = self._unwrap_value(
#     238                 response.get('value', None))
#
# C:\Users\amac\Anaconda3\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     190         elif exception_class == UnexpectedAlertPresentException and 'alert' in value:
#     191             raise exception_class(message, screen, stacktrace, value['alert'].get('text'))
# --> 192         raise exception_class(message, screen, stacktrace)
#     193
#     194     def _value_or_default(self, obj, key, default):
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="interview-invitation-popup-message"]"}
#   (Session info: chrome=56.0.2924.87)
#   (Driver info: chromedriver=2.27.440174 (e97a722caafc2d3a8b807ee115bfb307f7d2cfd9),platform=Windows NT 10.0.14393 x86_64)

# %%
df_1.head
# Out:
# <bound method NDFrame.head of                                             portrait_50  \
# 0     https://odesk-prod-portraits.s3.amazonaws.com/...
# 1     https://odesk-prod-portraits.s3.amazonaws.com/...
# 2     https://odesk-prod-portraits.s3.amazonaws.com/...
# 3     https://odesk-prod-portraits.s3.amazonaws.com/...
# 4     https://odesk-prod-portraits.s3.amazonaws.com/...
# 5     https://odesk-prod-portraits.s3.amazonaws.com/...
# 6     https://odesk-prod-portraits.s3.amazonaws.com/...
# 7     https://odesk-prod-portraits.s3.amazonaws.com/...
# 8     https://odesk-prod-portraits.s3.amazonaws.com/...
# 9     https://odesk-prod-portraits.s3.amazonaws.com/...
# 10    https://odesk-prod-portraits.s3.amazonaws.com/...
# 11    https://odesk-prod-portraits.s3.amazonaws.com/...
# 12    https://odesk-prod-portraits.s3.amazonaws.com/...
# 13    https://odesk-prod-portraits.s3.amazonaws.com/...
# 14    https://odesk-prod-portraits.s3.amazonaws.com/...
# 15    https://odesk-prod-portraits.s3.amazonaws.com/...
# 16    https://odesk-prod-portraits.s3.amazonaws.com/...
# 17    https://odesk-prod-portraits.s3.amazonaws.com/...
# 18    https://odesk-prod-portraits.s3.amazonaws.com/...
# 1980                  b'Freelance Writer of all Trades'
# 1981                     b'Writer, Editor, Coordinator'
# 1982                b'Sports Writing, Creative Writing'
# 1983                                 b'Creative Writer'
# 1984        b'Tech Support, Writer, Editor, Translator'
# 1985                  b'Owner of The Skilled Assistant'
# 1986  b'Freelance Writer- Biblical, Pastoral and Min...
# 1987           b'Journalist & Digital marketing expert'
# 1988             b'Skilled Proofreader and Copy Editor'
# 1989  b'Stock Writer, Equity Research, Report Writin...
# 1990  b'Content Writing, Social Media Management, an...
# 1991               b'Research developer - Forum poster'
# 1992  b'Content manager, virtual assistant and data ...
# 1993  b'Medical Writer, Article Writer, Editor, Tran...
# 1994         b'Writer/Creative Director/Video Producer'
# 1995  b'Food Labeling & Food Product Development Sci...
# 1996  b'Blogger, ebook writer, article writer, trans...
# 1997  b'Translating, website content, customer service'
# 1998                         b'Content/Creative Writer'
# 1999       b'Experienced Writer, Translator and Editor'
# 2000                                   b'Writer/Editor'
# 2001               b'Finance Professional & Freelancer'
# 2002  b'Freelance Writer & Virtual Assistant - Effic...
# 2003  b'Professional Freelance Writer and Editor wit...
# 2004                  b'Great writing and translations'
# 2005     b'Scientist/Writer/Consultant - Biotechnology'
# 2006  b'Stock Writer, Equity Research, Report Writin...
# 2007  b'Content Writing, Social Media Management, an...
# 2008    b'Web Research, SEO Writing, Virtual Assistant'
#
#                                             description         rate earned  \
# 0     The written word is my specialty! I am a freel...  $18.00 / hr  $400+
# 1     The written word is my specialty! I am a freel...  $11.00 / hr   $2k+
# 2     The written word is my specialty! I am a freel...  $15.00 / hr   $1k+
# 3     The written word is my specialty! I am a freel...  $16.66 / hr
# 4     The written word is my specialty! I am a freel...  $13.75 / hr
# 5     The written word is my specialty! I am a freel...  $25.00 / hr
# 6     The written word is my specialty! I am a freel...  $20.00 / hr
# 7     The written word is my specialty! I am a freel...  $11.25 / hr
# 8     The written word is my specialty! I am a freel...  $15.00 / hr
# 9     The written word is my specialty! I am a freel...  $12.00 / hr   $1k+
# 10    I am a native English speaker with over 10 yea...  $20.00 / hr  $10k+
# 11    I am a native English speaker with over 10 yea...  $15.00 / hr  $900+
# 12    I am a native English speaker with over 10 yea...  $20.00 / hr  $400+
# 13    I am a native English speaker with over 10 yea...  $15.00 / hr
# 14    I am a native English speaker with over 10 yea...  $22.00 / hr
# 15    I am a native English speaker with over 10 yea...  $20.00 / hr
# 16    I am a native English speaker with over 10 yea...  $25.00 / hr
# 17    I am a native English speaker with over 10 yea...  $15.00 / hr
# 18    I am a native English speaker with over 10 yea...  $30.00 / hr
# 19    I am a native English speaker with over 10 yea...  $18.00 / hr   $2k+
# 20    Writing has evolved over the years to a point ...  $15.00 / hr   $2k+
# 21    Writing has evolved over the years to a point ...  $20.00 / hr   $1k+
# 22    Writing has evolved over the years to a point ...  $12.00 / hr  $200+
# 23    Writing has evolved over the years to a point ...  $12.00 / hr
# 24    Writing has evolved over the years to a point ...  $12.00 / hr
# 25    Writing has evolved over the years to a point ...  $15.00 / hr
# 26    Writing has evolved over the years to a point ...  $24.00 / hr
# 27    Writing has evolved over the years to a point ...  $24.00 / hr
# 28    Writing has evolved over the years to a point ...  $25.00 / hr
# 29    Writing has evolved over the years to a point ...  $12.00 / hr   $20+
# ...                                                 ...          ...    ...
# 1979  b'I am a native German professional within Wri...  $16.70 / hr
# 1980  b'I am a native German professional within Wri...  $28.00 / hr
# 1981  b'I earned my degree in Communications and Jou...  $30.00 / hr
# 1982  b'I earned my degree in Communications and Jou...  $15.00 / hr
# 1983  b'I earned my degree in Communications and Jou...  $11.00 / hr
# 1984  b'I earned my degree in Communications and Jou...  $16.99 / hr
# 1985  b'I earned my degree in Communications and Jou...  $30.00 / hr
# 1986  b'I earned my degree in Communications and Jou...  $13.50 / hr
# 1987  b'I earned my degree in Communications and Jou...  $12.50 / hr
# 1988  b'I earned my degree in Communications and Jou...  $18.75 / hr
# 1989  b'I earned my degree in Communications and Jou...  $12.00 / hr
# 1990  b'I earned my degree in Communications and Jou...  $18.00 / hr
# 1991  b'I am currently studying full time MBA at Uni...  $18.00 / hr
# 1992  b'I am currently studying full time MBA at Uni...  $18.00 / hr
# 1993  b'I am currently studying full time MBA at Uni...  $15.00 / hr
# 1994  b'I am currently studying full time MBA at Uni...  $30.00 / hr
# 1995  b'I am currently studying full time MBA at Uni...  $25.00 / hr
# 1996  b'I am currently studying full time MBA at Uni...  $13.00 / hr
# 1997  b'I am currently studying full time MBA at Uni...  $13.00 / hr
# 1998  b'I am currently studying full time MBA at Uni...  $30.00 / hr
# 1999  b'I am currently studying full time MBA at Uni...  $11.11 / hr
# 2000  b'I am currently studying full time MBA at Uni...  $22.00 / hr
# 2001  b'My name is Lincoln and I am currently seekin...  $12.00 / hr
# 2002  b'My name is Lincoln and I am currently seekin...  $14.00 / hr
# 2003  b'My name is Lincoln and I am currently seekin...  $25.00 / hr
# 2004  b'My name is Lincoln and I am currently seekin...  $11.11 / hr
# 2005  b'My name is Lincoln and I am currently seekin...  $15.00 / hr
# 2006  b'My name is Lincoln and I am currently seekin...  $12.00 / hr
# 2007  b'My name is Lincoln and I am currently seekin...  $18.00 / hr
# 2008  b'My name is Lincoln and I am currently seekin...  $18.75 / hr
#
#               feedback               country    filename worked jobs  \
# 0                  NaN         United States  people.csv     20    2
# 1      95% Job Success            Bangladesh  people.csv     12   57
# 2      92% Job Success              Pakistan  people.csv     18   29
# 3     100% Job Success               Romania  people.csv
# 4      91% Job Success            Bangladesh  people.csv
# 5        RISING TALENT         United States  people.csv
# 6                  NaN         United States  people.csv
# 7      92% Job Success                 India  people.csv
# 8                  NaN              Pakistan  people.csv
# 9      88% Job Success                Canada  people.csv     18   25
# 10    100% Job Success                Latvia  people.csv    285   44
# 11     96% Job Success         United States  people.csv     18   27
# 12     78% Job Success                 India  people.csv      3   21
# 13    100% Job Success              Pakistan  people.csv
# 14    100% Job Success         United States  people.csv
# 15     83% Job Success                 India  people.csv
# 16     75% Job Success                 Kenya  people.csv
# 17     84% Job Success         United States  people.csv
# 18                 NaN                Canada  people.csv
# 19     81% Job Success         United States  people.csv     13   27
# 20     80% Job Success         United States  people.csv     81   22
# 21     97% Job Success         United States  people.csv      4   12
# 22     83% Job Success               Romania  people.csv     34    7
# 23     75% Job Success            Bangladesh  people.csv
# 24     94% Job Success  United Arab Emirates  people.csv
# 25     99% Job Success           Philippines  people.csv
# 26     95% Job Success        United Kingdom  people.csv
# 27     98% Job Success           Philippines  people.csv
# 28     92% Job Success           Philippines  people.csv
# 29                 NaN            Costa Rica  people.csv      2    2
# ...                ...                   ...         ...    ...  ...
# 1979   83% Job Success         United States  people.csv
# 1980   91% Job Success         United States  people.csv
# 1981  100% Job Success         United States  people.csv
# 1982  100% Job Success                 India  people.csv
# 1983               NaN         United States  people.csv
# 1984  100% Job Success           New Zealand  people.csv
# 1985   94% Job Success         United States  people.csv
# 1986  100% Job Success         United States  people.csv
# 1987  100% Job Success                Serbia  people.csv
# 1988   97% Job Success         United States  people.csv
# 1989   98% Job Success                 India  people.csv
# 1990  100% Job Success         United States  people.csv
# 1991               NaN                Cyprus  people.csv
# 1992  100% Job Success             Hong Kong  people.csv
# 1993   76% Job Success         United States  people.csv
# 1994   92% Job Success         United States  people.csv
# 1995               NaN                 Italy  people.csv
# 1996  100% Job Success              Honduras  people.csv
# 1997     RISING TALENT               Bolivia  people.csv
# 1998  100% Job Success         United States  people.csv
# 1999  100% Job Success             Australia  people.csv
# 2000   92% Job Success         United States  people.csv
# 2001  100% Job Success         United States  people.csv
# 2002   93% Job Success         United States  people.csv
# 2003               NaN         United States  people.csv
# 2004   89% Job Success         United States  people.csv
# 2005   75% Job Success                Canada  people.csv
# 2006   98% Job Success                 India  people.csv
# 2007  100% Job Success         United States  people.csv
# 2008   93% Job Success             Macedonia  people.csv
#
#        accolade           success  \
# 0
# 1     TOP RATED   95% Job Success
# 2     TOP RATED   92% Job Success
# 3
# 4
# 5
# 6
# 7
# 8
# 9                 88% Job Success
# 10    TOP RATED  100% Job Success
# 11    TOP RATED   96% Job Success
# 12                78% Job Success
# 13
# 14
# 15
# 16
# 17
# 18
# 19                81% Job Success
# 20                80% Job Success
# 21                97% Job Success
# 22                83% Job Success
# 23
# 24
# 25
# 26
# 27
# 28
# 29
# ...         ...               ...
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
#
#                                            availability messaged  \
# 0     AvailableAs Needed - Open to OffersAvailableAs...       NA
# 1     AvailableMore than 30 hrs/weekAvailableMore th...       NA
# 2     AvailableAs Needed - Open to OffersAvailableAs...       NA
# 3
# 4
# 5
# 6
# 7
# 8
# 9     AvailableAs Needed - Open to OffersAvailableAs...       NA
# 10    AvailableAs Needed - Open to OffersAvailableAs...       NA
# 11    AvailableLess than 30 hrs/weekAvailableLess th...       NA
# 12    AvailableMore than 30 hrs/weekAvailableMore th...       NA
# 13
# 14
# 15
# 16
# 17
# 18
# 19    AvailableMore than 30 hrs/weekAvailableMore th...       NA
# 20    AvailableMore than 30 hrs/weekAvailableMore th...       NA
# 21    AvailableAs Needed - Open to OffersAvailableAs...       NA
# 22    AvailableAs Needed - Open to OffersAvailableAs...       NA
# 23
# 24
# 25
# 26
# 27
# 28
# 29    AvailableMore than 30 hrs/weekAvailableMore th...       NA
# ...                                                 ...      ...
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
#
#      job_in_progress scraped_rate                      language  \
# 0                  1       $18.00  English: Native or Bilingual
# 1                 19       $11.00               English: Fluent
# 2                 10       $15.00               English: Fluent
# 3
# 4
# 5
# 6
# 7
# 8
# 9                  5       $12.00  English: Native or Bilingual
# 10                10       $20.00  English: Native or Bilingual
# 11                 7       $15.00  English: Native or Bilingual
# 12                 0        $5.00               English: Fluent
# 13
# 14
# 15
# 16
# 17
# 18
# 19                 6       $18.00  English: Native or Bilingual
# 20                11       $15.00  English: Native or Bilingual
# 21                 7       $20.00  English: Native or Bilingual
# 22                 2       $12.00               English: Fluent
# 23
# 24
# 25
# 26
# 27
# 28
# 29                 1       $12.00  English: Native or Bilingual
# ...              ...          ...                           ...
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
#
#                                                 college
# 0     b'Associate of Arts and Sciences (A.A.S.), Lib...
# 1     b'Bachelor of Arts (B.A.), English | Banglades...
# 2     b"Other, O'levels Business Studies | Beaconhou...
# 3
# 4
# 5
# 6
# 7
# 8
# 9     b'Master of Arts (M.A.), English literature | ...
# 10              b'Queensferry High School\n1983 - 1988'
# 11    b'Bachelor of Arts (B.A.), Creative Writing | ...
# 12    b'Bachelor of Engineering (B.Eng.), Computer s...
# 13
# 14
# 15
# 16
# 17
# 18
# 19
# 20    b'Master of Computer Applications (M.C.A.), Co...
# 21    b'English | MiraCosta College\n2015 - 2019 (ex...
# 22    b'High school degree, Iasi | Faculty of Comput...
# 23
# 24
# 25
# 26
# 27
# 28
# 29    b'Bachelor of Arts (B.A.), Deaf Studies | Cal ...
# ...                                                 ...
# 1979
# 1980
# 1981
# 1982
# 1983
# 1984
# 1985
# 1986
# 1987
# 1988
# 1989
# 1990
# 1991
# 1992
# 1993
# 1994
# 1995
# 1996
# 1997
# 1998
# 1999
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
#
# [2000 rows x 20 columns]>

# %%
df2.shape

# %%
df2=df2[121:]

# %%
df2.shape
# Out:
# (4663, 10)

# %%
df2=df2[723:]

# %%
df2.shape
# Out:
# (3800, 10)
